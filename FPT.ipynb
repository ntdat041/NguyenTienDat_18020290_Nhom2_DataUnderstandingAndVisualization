# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

# %%
FPT = pd.read_csv('FPT.csv')

# %%
FPT['Type'].value_counts()
# Out:
# Máy tính xách tay    94
# Điện thoại           75
# Máy tính bảng        32
# Name: Type, dtype: int64

# %%
Laptop = FPT[FPT['Type'] == 'Máy tính xách tay']
Phone = FPT[FPT['Type'] == 'Điện thoại']
Tablet = FPT[FPT['Type'] == 'Máy tính bảng']

# %%
# create a figure and axis
fig, ax = plt.subplots()

# scatter the sepal_length against the sepal_width
ax.scatter(Laptop['Current Price'],Laptop['Rate'])
# set a title and labels
ax.set_title('Laptop Dataset')
ax.set_xlabel('Price')
ax.set_ylabel('Rate')
# Out:
# Text(0, 0.5, 'Rate')

# %%
fig, ax = plt.subplots()

ax.scatter(Phone['Current Price'],Phone['Rate'])

ax.set_title('Phone Dataset')
ax.set_xlabel('Price')
ax.set_ylabel('Rate')
# Out:
# Text(0, 0.5, 'Rate')

# %%
fig, ax = plt.subplots()

ax.scatter(Tablet['Current Price'],Tablet['Rate'])

ax.set_title('Tablet Dataset')
ax.set_xlabel('Price')
ax.set_ylabel('Rate')
# Out:
# Text(0, 0.5, 'Rate')

# %%
# create color dictionary
colors = {'Máy tính xách tay':'r', 'Điện thoại':'g',  'Máy tính bảng':'b'}
# create a figure and axis
fig, ax = plt.subplots()
# plot each data-point
for i in range(len(FPT['Current Price'])):
    ax.scatter(FPT['Current Price'][i], FPT['Rate'][i],color=colors[FPT['Type'][i]])
# set a title and labels
ax.set_title('FPT Dataset')
ax.set_xlabel('Price')
ax.set_ylabel('Rate')
# Out:
# Text(0, 0.5, 'Rate')

# %%
# create a figure and axis 
fig, ax = plt.subplots() 
# count the occurrence of each class 
data = FPT['Type'].value_counts()
# get x and y data 
types = data.index
number = data.values 
# create bar chart 
ax.bar(types,number) 
# set title and labels 
ax.set_title('FPT Shop') 
ax.set_xlabel('') 
ax.set_ylabel('Số lượng')
# Out:
# Text(0, 0.5, 'Số lượng')

# %%
sns.scatterplot(x='Current Price', y='Rate',hue='Type', data=FPT)

# %%
sns.countplot(FPT['Rate'])

# %%
sns.boxplot(x=FPT['Current Price'])

plt.show()

# %%
sns.boxplot(x="Type", y="Current Price", data=FPT)

plt.show()

# %%
sns.violinplot(x="Type", y="Current Price", data=FPT)

plt.show()

# %%
sns.pointplot(x="Rate", y="Current Price", data=FPT)

plt.show()

# %%
price = FPT['Current Price']
types = FPT['Type'] 
rate = FPT['Rate']

# %%
plt.bar(rate, price)
plt.show()

# %%
fig = plt.gcf()
fig.set_size_inches(8,8)
data = FPT['Type'].value_counts()
types = data.index
number = data.values 
plt.pie(number, labels = types)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
